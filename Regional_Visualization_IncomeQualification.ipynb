# %% [markdown]
# # Income Qualification EDA

# %%
import os
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from pandas import Series, DataFrame
# %matplotlib inline

# %%
os.chdir("F:\\Vibhuti\\business analytics and intelligence\\simplilearn\\machinelearning\\ML_Projects_Simplilearn\\IncomeQualification")

# %%
df = pd.read_csv("train.csv",engine='python')

# %%
df.head(5)
# Out:
#              Id      v2a1  hacdor  rooms  hacapo  v14a  refrig  v18q  v18q1  \
# 0  ID_279628684  190000.0       0      3       0     1       1     0    NaN
# 1  ID_f29eb3ddd  135000.0       0      4       0     1       1     1    1.0
# 2  ID_68de51c94       NaN       0      8       0     1       1     0    NaN
# 3  ID_d671db89c  180000.0       0      5       0     1       1     1    1.0
# 4  ID_d56d6f5f5  180000.0       0      5       0     1       1     1    1.0
#
#    r4h1  ...  SQBhogar_total  SQBedjefe  SQBhogar_nin  SQBovercrowding  \
# 0     0  ...               1        100             0         1.000000
# 1     0  ...               1        144             0         1.000000
# 2     0  ...               1          0             0         0.250000
# 3     0  ...              16        121             4         1.777778
# 4     0  ...              16        121             4         1.777778
#
#    SQBdependency  SQBmeaned  agesq  Target   Region   Area
# ...

# %%
x = df['Target'].value_counts(normalize=True) * 100

# %%
#colors_list = ['#5cb85c','#5bc0de','#d9534f','#d9534y']

colors_list = ['red','yellow','orange','purple']

# %%
x.plot(kind="bar", stacked=True, color = colors_list)

# %%
x
# Out:
# 4    62.739353
# 2    16.710265
# 3    12.650413
# 1     7.899969
# Name: Target, dtype: float64

# %%
ax = sns.countplot(y="Target", data=df)
plt.title('Distribution of Poverty Level')
plt.xlabel('Count'); 
plt.ylabel('Poverty Level'); 

total = len(df['Target'])
for p in ax.patches:
        percentage = '{:.1f}%'.format(100 * p.get_width()/total)
        x = p.get_x() + p.get_width() + 2
        y = p.get_y() + p.get_height()/2
        ax.annotate(percentage, (x, y))

plt.show()

# %%
from collections import OrderedDict
# Color mapping
colors = OrderedDict({1: 'red', 2: 'orange', 3: 'blue', 4: 'green'})
poverty_mapping = OrderedDict({1: 'extreme', 2: 'moderate', 3: 'vulnerable', 4: 'non vulnerable'})

# %%
# Value counts of target
label_counts = df['Target'].value_counts().sort_index()

# Bar plot of occurrences of each label
label_counts.plot.bar(figsize = (8, 6), 
                      color = colors.values(),
                      edgecolor = 'k', linewidth = 2)

# labels and titles
plt.xlabel('Poverty Level'); plt.ylabel('Count'); 
plt.xticks([x - 1 for x in poverty_mapping.keys()], 
           list(poverty_mapping.values()), rotation = 360)
plt.title('Poverty Level Breakdown');

total = len(df['Target'])
for p in ax.patches:
        percentage = '{:.1f}%'.format(100 * p.get_width()/total)
        x = p.get_x() + p.get_width() + 2
        y = p.get_y() + p.get_height()/2
        ax.annotate(percentage, (x, y))

plt.show()

# %%
df['hacdor'].value_counts()
# Out:
# 0    9193
# 1     364
# Name: hacdor, dtype: int64

# %%
from collections import OrderedDict

# %%
df[df['lugar1']==1].count()
# Out:
# Id           5616
# v2a1         1858
# hacdor       5616
# rooms        5616
# hacapo       5616
#              ...
# SQBmeaned    5611
# agesq        5616
# Target       5616
# Region       5616
# Area         5616
# Length: 145, dtype: int64

# %%
df['Region']
# Out:
# 0            Central
# 1            Central
# 2            Central
# 3            Central
# 4            Central
#             ...
# 9552    Huetar Norte
# 9553    Huetar Norte
# 9554    Huetar Norte
# 9555    Huetar Norte
# 9556    Huetar Norte
# Name: Region, Length: 9557, dtype: object

# %%
a = df[df['Region']=='Central']['Target']

# %%
sns.boxplot(df['Region'], df['Target'])

# %%
df['Region'].value_counts().sort_index().plot.bar()

# %%
df['Target'].value_counts().sort_index().plot.barh()

# %%
sns.countplot(df['Target'],hue = df['Region'] )

# %%
sns.countplot(x= 'parentesco1', hue = 'Target', data = df)

# %%
sns.stripplot(x='escolari', y='Target',data = df, jitter=True)

# %%
sns.jointplot(x='meaneduc', y='Target',data = df, kind = 'kde')
# Out:
# D:\anaconda\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.countplot(x='r4h3', data = df)
plot1 =plt.xlabel("Males in the household")
plot2 =plt.xlabel("Females in the household")

# %%
sns.countplot(x='r4m3', data = df)
plt.xlabel("Females in the household")
# Out:
# Text(0.5, 0, 'Females in the household')

# %%
plt.figure(figsize=(15,10))
fig, ax =plt.subplots(1,2)
sns.countplot(x='r4m3', data = df, ax=ax[0])
sns.countplot(x='r4h3', data = df, ax=ax[1])
fig.show()
# Out:
# D:\anaconda\lib\site-packages\matplotlib\figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())

# %%
df['r4h3'].value_counts()
# Out:
# 2    3211
# 1    3142
# 3    1760
# 0     628
# 4     507
# 5     181
# 6      94
# 7      24
# 8      10
# Name: r4h3, dtype: int64

# %%
df['r4m3'].value_counts()
# Out:
# 2    3230
# 1    3203
# 3    1707
# 4     757
# 0     328
# 5     165
# 6     119
# 7      39
# 8       9
# Name: r4m3, dtype: int64

# %%
plt.figure(figsize=(15,10))
fig, ax =plt.subplots(1,2)
sns.countplot(x='tamhog', data = df, ax=ax[0])
sns.countplot(x='tamviv', data = df, ax=ax[1])
fig.suptitle('Horizontally stacked subplots')
fig.show()
# Out:
# D:\anaconda\lib\site-packages\matplotlib\figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())

# %%
sns.jointplot(x='tamhog', y = 'tamviv', data = df)
plt.xlabel("Size of the household")
plt.ylabel("No. of persons in the household")
# Out:
# Text(336.9714285714286, 0.5, 'No. of persons in the household')

# %%
sns.swarmplot(x='Target', y = 'hhsize', data = df)
plt.xlabel("Poverty level")
plt.ylabel("Size of the house")
# Out:
# Text(0, 0.5, 'Size of the house')

# %%
sns.boxplot(x='Target', hue= 'Region', data = df)

# %%
df['dependency'].replace('yes', '1', inplace= True)
df['dependency'].replace('no', '0', inplace= True)
df['edjefe'].replace('yes', '1', inplace= True)
df['edjefe'].replace('no', '0', inplace= True)
df['edjefa'].replace('yes', '1', inplace= True)
df['edjefa'].replace('no', '0', inplace= True)

# %%
df.columns
# Out:
# Index(['Id', 'v2a1', 'hacdor', 'rooms', 'hacapo', 'v14a', 'refrig', 'v18q',
#        'v18q1', 'r4h1',
#        ...
#        'SQBhogar_total', 'SQBedjefe', 'SQBhogar_nin', 'SQBovercrowding',
#        'SQBdependency', 'SQBmeaned', 'agesq', 'Target', 'Region', 'Area'],
#       dtype='object', length=145)

# %%
df['Area']
# Out:
# 0       Urban
# 1       Urban
# 2       Urban
# 3       Urban
# 4       Urban
#         ...
# 9552    Rural
# 9553    Rural
# 9554    Rural
# 9555    Rural
# 9556    Rural
# Name: Area, Length: 9557, dtype: object

# %%
sns.barplot(x='Target', y='Area', hue = 'Target', data = df)

# %%
plt.figure(figsize=(10,5))
sns.barplot(x = 'Region', y  ='Target', data = df)
plt.xlabel("Region")
plt.ylabel("Target")
plt.title("Region and Target")
# Out:
# Text(0.5, 1.0, 'Region and Target')

# %%
sns.barplot(x= 'tipovivi5', y='Target', data = df)

# %%
f, axes = plt.subplots(2, 2)

# %%
fig, axes = plt.subplots(3, 2)
sns.barplot(  x= 'tipovivi1', y='Target', data = df , ax=axes[0,0])
sns.barplot(  x= 'tipovivi2', y='Target', data = df,  ax=axes[0,1])
sns.barplot(  x= 'tipovivi3', y='Target', data = df,   ax=axes[1,0])
sns.barplot(  x= 'tipovivi4', y='Target', data = df,   ax=axes[1,1])
sns.barplot(  x= 'tipovivi5', y='Target', data = df,   ax=axes[2,0])

# %% [markdown]
# # Thank You!!
